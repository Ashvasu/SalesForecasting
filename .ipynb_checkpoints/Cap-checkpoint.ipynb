# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
from statsmodels.formula.api import ols      # For n-way ANOVA
from statsmodels.stats.anova import _get_covariance,anova_lm # For n-way ANOVA
# %matplotlib inline
from statsmodels.graphics.factorplots import interaction_plot
import plotly.express as px
import pywedge as pw

# %%
df=pd.read_csv('Forecast.csv')

# %%
df.head()

# %%
df.isnull().sum()
# Out:
# product    0
# date       0
# city       0
# sales      0
# dtype: int64

# %%
df.head()
# Out:
#   product        date    city    sales
# 0  Mixers  04-01-2014  Mumbai  2679347
# 1  Mixers  05-01-2014  Mumbai  3864612
# 2  Mixers  06-01-2014  Mumbai  2932658
# 3  Mixers  07-01-2014  Mumbai  3703713
# 4  Mixers  08-01-2014  Mumbai  3931029

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4800 entries, 0 to 4799
# Data columns (total 4 columns):
# product    4800 non-null object
# date       4800 non-null datetime64[ns]
# city       4800 non-null object
# sales      4800 non-null int64
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 150.1+ KB

# %%
import datetime

# %%
df['date'] = df["date"].dt.strftime("%m-%d-%y")

# %%
def univariateAnalysis_numeric(column,nbins):
    print("Description of " + column)
    print("----------------------------------------------------------------------------")
    print(df[column].describe(),end=' ')
    
    
    plt.figure()
    print("Distribution of " + column)
    print("----------------------------------------------------------------------------")
    fig = px.histogram(df, x= column)
    fig.show()
    
    plt.figure()
    print("BoxPlot of " + column)
    print("----------------------------------------------------------------------------")
    fig = px.box(df, x= column)
    fig.show()

# %%
df_num = df.select_dtypes(include = ['float64', 'int64'])
lstnumericcolumns = list(df_num.columns.values)
len(lstnumericcolumns)
# Out:
# 1

# %%
for x in lstnumericcolumns:
    univariateAnalysis_numeric(x,20);
# Out:
# Description of sales
# ----------------------------------------------------------------------------
# count    4.800000e+03
# mean     7.415188e+05
# std      1.308447e+06
# min      0.000000e+00
# 25%      1.171152e+05
# 50%      3.077215e+05
# 75%      7.796660e+05
# max      1.588133e+07
# Name: sales, dtype: float64 Distribution of sales
# ----------------------------------------------------------------------------
# <div>                            <div id="76e2d38d-c049-4df4-b806-876461a007af" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76e2d38d-c049-4df4-b806-876461a007af")) {                    Plotly.newPlot(                        "76e2d38d-c049-4df4-b806-876461a007af",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"sales=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"type":"histogram","x":[2679347,3864612,2932658,3703713,3931029,4677008,4331662,2184730,4131878,4043952,3276885,5043804,3625236,4326062,2418609,3937404,3708630,3804926,5417580,2938341,4300940,3229175,3267240,6103232,5736690,3515403,1983288,3723448,4012728,5112100,5203170,2197132,2906503,3926367,3637237,5661553,2173903,4273063,3628117,5514155,6511352,7282989,7769826,2595569,4306914,6261570,2344462,3875078,1028092,1482890,1125290,1421152,1508375,1794615,1662102,838303,1585443,1551705,1257373,1935358,1377305,1643564,918881,1495904,1408988,1445573,2058255,1116339,1634019,1226833,1241295,2318749,2371726,1453377,819953,1539389,1658986,2113501,2151152,908362,1201639,1623282,1
1077551,946311,1364932,1035778,1308104,1388389,1651860,1529888,771619,1459327,1428273,1157354,1781407,900866,1075020,601021,978439,921589,945518,1346260,730173,1068777,802445,811904,1516644,1187626,727769,410586,770839,830726,1058321,1077175,454856,601712,812847,752991,1172070,730680,1331748,1678719,2062534,1635874,2363514,2341632,650167,1468291,1359409,868654,1296810,282973,408152,309726,391159,415166,493951,45 ...

# %%
df_num.skew()
# Out:
# sales    4.596524
# dtype: float64

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.countplot(x="city", data=df, ax=ax);

# %%
a4_dims = (20, 20)
fig, ax = plt.subplots(figsize=a4_dims)
sns.countplot(x="product", data=df, ax=ax);

# %%
a4_dims = (100,100)
fig, ax = plt.subplots(figsize=a4_dims)
sns.countplot(x="date", data=df, ax=ax);

# %%
df.to_excel(r'D:\Great lakes\Capstone\Forecasting Project\Forecaste.xlsx', index = False)

# %%
df.plot()
plt.grid();

# %%
df1=pd.read_csv('Forecast.csv',parse_dates = True, index_col = 'date')

# %%
# The following code is to set the subsequent figure sizes

from pylab import rcParams
rcParams['figure.figsize'] = 40,40

# %%
df1.plot()
plt.grid();

# %%
df1['sales'] = df1['sales'].astype(float)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4800 entries, 2014-04-01 to 2018-03-01
# Data columns (total 3 columns):
# product    4800 non-null object
# city       4800 non-null object
# sales      4800 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 150.0+ KB

# %%
sns.boxplot(x = df1.index.year,y = df['sales'])
plt.grid();

# %%
sns.boxplot(x = df1.index.month_name(),y = df1['sales'])
plt.grid();

# %%
monthly_sales_across_years = pd.pivot_table(df, values = 'sales', columns = df1.index.month, index = df1.index.year)
monthly_sales_across_years
# Out:
# date         1          2           3           4          5          6   \
# date
# 2014        NaN        NaN         NaN   668742.55  574005.99  380022.79
# 2015  563925.23  673783.29  1013884.26   772012.47  648174.78  339858.57
# 2016  490471.80  670827.42  1142118.89  1249443.34  633803.31  330192.81
# 2017  661150.45  893454.29  1343084.68  1029636.12  916768.21  615667.67
# 2018  894295.41  978819.97  1401997.95         NaN        NaN        NaN
#
# date         7          8           9           10         11         12
# date
# 2014  499216.46  514515.92   602927.63   651642.67  376612.96  608556.72
# 2015  560758.33  519871.89   533117.83   831971.20  498186.52  671479.16
# 2016  616433.93  629727.49   773065.86   972123.07  535053.11  635116.45
# 2017  887860.21  932772.40  1048985.46  1308493.58  623829.29  874442.80
# 2018        NaN        NaN         NaN         NaN        NaN        NaN

# %%
monthly_sales_across_years.plot()
plt.grid()
plt.legend(loc='best');

# %%
plt.figure(figsize = (18, 8))
cdf = ECDF(df1['sales'])
plt.plot(cdf.x, cdf.y, label = "statmodels");
plt.grid()
plt.xlabel('Sales');

# %%
sns.pairplot(df)
